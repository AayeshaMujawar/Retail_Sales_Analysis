# %%
from IPython.display import HTML

HTML('''
<style>
div.input {display:none;}
</style>
''')





# %matplotlib inline
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# MySQL connection
conn = mysql.connector.connect(
    host="localhost",      
    user="root",           
    password="Mujawar123#", 
    database="retail_db"
)

print("✅ Connected to MySQL!")

# Orders table ka data fetch karna
query = "SELECT * FROM Orders;"

conn.close()

# Data display
df.head()
# Out:
# ✅ Connected to MySQL!
#    order_id  customer_id  order_date  total_amount payment_method     status
# 0         1            1  2025-10-10        2298.0         Online  Delivered
# 1         2            2  2025-10-12          49.0            COD  Delivered
# 2         3            3  2025-10-15         299.0            UPI  Delivered
# 3         4            4  2025-10-18        8999.0           Card    Pending

# %%
plt.figure(figsize=(6,4))
plt.bar(df['order_id'], df['total_amount'], color='teal')
plt.title('Order-wise Total Sales')
plt.xlabel('Order ID')
plt.ylabel('Total Amount (₹)')
plt.show()

plt.figure(figsize=(6,4))
sns.countplot(x='payment_method', data=df, palette='pastel')
plt.title('Payment Method Distribution')
plt.xlabel('Payment Method')
plt.ylabel('Number of Orders')
plt.show()

plt.figure(figsize=(5,4))
sns.countplot(x='status', data=df, palette='Set2')
plt.title('Order Status Overview')
plt.xlabel('Status')
plt.ylabel('Count')
plt.show()

# %%
# !jupyter nbconvert "Untitled3.ipynb" --to html --no-input
# Out:
# [NbConvertApp] Converting notebook Untitled3.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 3 image(s).
# [NbConvertApp] Writing 330660 bytes to Untitled3.html
